# %%
import os
from google.colab import drive
drive.mount('/content/drive')
os.chdir("./drive/MyDrive/git_project/AnomalyDetection")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git add .

# %%
# !git reset 1edc8c043b2d27d148cb77bf94ddce52e360921c
# Out:
# Unstaged changes after reset:
# M	.gitignore
# M	GitCommit.ipynb
# M	docker-compose.yml
# M	notebook/DownloadMvTecDataset.ipynb
# M	notebook/Sample_mvtec.ipynb
# M	src/dataset/datasets.py
# M	src/dataset/utils.py
# M	src/model/models.py
# D	src/train.py
# M	src/utils.py

# %%
# !git config --global user.email 'dnsgus6035@gmail.com'
# !git config --global user.name 'naninya'

# %%
# !git commit -m "refactoring"
# Out:
# [main 8afed88] refactoring
#  18 files changed, 337 insertions(+), 117 deletions(-)
#  rewrite GitCommit.ipynb (67%)
#  create mode 100644 gitignore
#  create mode 100644 models/bottle/512/faiss_weight
#  create mode 100644 models/grid/512/faiss_weight
#  create mode 100644 models/toothbrush/512/faiss_weight
#  create mode 100644 models/zipper/512/faiss_weight
#  rewrite notebook/DownloadMvTecDataset.ipynb (93%)
#  rewrite notebook/Sample_mvtec.ipynb (99%)
#  create mode 100644 src/configs.py
#  create mode 100644 src/testers.py
#  delete mode 100644 src/train.py
#  create mode 100644 src/trainers.py

# %%
# !git status
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git push origin main
# Out:
# Enumerating objects: 46, done.
# Counting objects: 100% (46/46), done.
# Delta compression using up to 2 threads
# ^C
