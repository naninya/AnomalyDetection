# %%
# Data Load:..

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
os.chdir("./drive/MyDrive/git_project/AnomalyDetection/src")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_dir = "../data"

# %%
# Download Datasets

# %%
# https://www.mvtec.com/company/research/datasets/mvtec-ad/downloads
os.listdir(data_dir)
# Out:
# ['grid.tar.xz', 'bottle.tar.xz', 'zipper.tar.xz', 'toothbrush.tar.xz']

# %%
# !tar -xf ../data/bottle.tar.xz -C ../data
# !tar -xf ../data/grid.tar.xz -C ../data
# !tar -xf ../data/zipper.tar.xz -C ../data
# !tar -xf ../data/toothbrush.tar.xz -C ../data
# !chmod 777 -R ../data
